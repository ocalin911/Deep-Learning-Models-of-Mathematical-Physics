# %% [markdown]
# <a href="https://colab.research.google.com/github/ocalin911/Deep-Learning-Models-of-Mathematical-Physics/blob/Volume-I/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The Direct Method**

# %% [markdown]
# We start by graphing the polynomial function $f(x) = x^3 - 2x^2 + 4x - 8$. We use the domain D=[-5, 7], where the root x=2 is situated, using 400 points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def P(x):
    return x**3 - 2*x**2 + 4*x - 8

# Generate a range of x values
x = np.linspace(-5, 7, 400)
y = f(x)

# Create the plot
plt.figure(figsize=(8,6))
plt.plot(x, y, label=r'$P(x)=x^3 - 2x^2 + 4x - 8$')
plt.axhline(0, color='black', linewidth=0.5)  # x-axis
plt.axvline(0, color='black', linewidth=0.5)  # y-axis
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Graph of $P(x)=x^3 - 2x^2 + 4x - 8$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The following is a Keras implementation using a 1-hiden layer neural network to find the solution of P(x) = 0. For training purposses a dummy traget has been used.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define the algebraic function
def f(x):
    return x**3 - 2*x**2 + 4*x - 8

# Neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(20, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

# Custom loss function that depends only on the model output.
def custom_loss(y_true, y_pred):
    # y_true is a dummy target and is ignored.
    # The loss is the mean squared value of f(x_NN)
    return tf.reduce_mean(tf.square(f(y_pred)))

# Compile the model using the custom loss and an optimizer (Adam in this case)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.02)
model.compile(optimizer=optimizer, loss=custom_loss)

# Since our loss function doesn't require actual target values,
# we create dummy targets. We use the same dummy value for each sample.
t = 1.0 #this is the input to the NN. It can be any number.
dummy_input = np.array([[t]])
dummy_target = np.array([[0.0]])

# Train the model using model.fit; here, we only have one data point.
model.fit(dummy_input, dummy_target, epochs=300, verbose=2)

# Extract the solution by querying the network with the same dummy input
x_solution = model(tf.constant([[t]])).numpy()[0, 0]
print(f"Approximate solution: x = {x_solution}")
# Out:
# Epoch 1/300
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 - 1s - 798ms/step - loss: 97.1754
# Epoch 2/300
# 1/1 - 0s - 74ms/step - loss: 71.8019
# Epoch 3/300
# 1/1 - 0s - 40ms/step - loss: 55.9476
# Epoch 4/300
# 1/1 - 0s - 42ms/step - loss: 45.1785
# Epoch 5/300
# 1/1 - 0s - 42ms/step - loss: 37.0458
# Epoch 6/300
# 1/1 - 0s - 60ms/step - loss: 30.1031
# Epoch 7/300
# 1/1 - 0s - 59ms/step - loss: 23.4728
# Epoch 8/300
# 1/1 - 0s - 60ms/step - loss: 16.6893
# Epoch 9/300
# 1/1 - 0s - 40ms/step - loss: 9.7646
# Epoch 10/300
# 1/1 - 0s - 59ms/step - loss: 3.5075
# Epoch 11/300
# 1/1 - 0s - 60ms/step - loss: 0.0646
# Epoch 12/300
# 1/1 - 0s - 42ms/step - loss: 2.7384
# Epoch 13/300
# 1/1 - 0s - 41ms/step - loss: 10.0850
# Epoch 14/300
# 1/1 - 0s - 67ms/step - loss: 12.6972
# Epoch 15/300
# 1/1 - 0s - 56ms/step - loss: 9.1983
# Epoch 16/300
# 1/1 - 0s - 56ms/step - loss: 4.1865
# Epoch 17/300
# 1/1 - 0s - 61ms/step - loss: 0.9282
# Epoch 18/300
# 1/1 - 0s - 42ms/step - loss: 3.3815e-05
# Epoch 19/300
# 1/1 - 0s - 61ms/step - loss: 0.6071
# Epoch 20/300
# 1/1 - 0s - 43ms/step - loss: 1.8217
# Epoch 21/300
# 1/1 - 0s - 59ms/step - loss: 3.0311
# Epoch 22/300
# 1/1 - 0s - 42ms/step - loss: 3.9270
# Epoch 23/300
# 1/1 - 0s - 60ms/step - loss: 4.3924
# Epoch 24/300
# 1/1 - 0s - 40ms/step - loss: 4.4128
# Epoch 25/300
# 1/1 - 0s - 60ms/step - loss: 4.0309
# Epoch 26/300
# 1/1 - 0s - 44ms/step - loss: 3.3270
# Epoch 27/300
# 1/1 - 0s - 41ms/step - loss: 2.4167
# Epoch 28/300
# 1/1 - 0s - 42ms/step - loss: 1.4520
# Epoch 29/300
# 1/1 - 0s - 60ms/step - loss: 0.6165
# Epoch 30/300
# 1/1 - 0s - 41ms/step - loss: 0.0988
# Epoch 31/300
# 1/1 - 0s - 42ms/step - loss: 0.0303
# Epoch 32/300
# 1/1 - 0s - 42ms/step - loss: 0.3958
# Epoch 33/300
# 1/1 - 0s - 64ms/step - loss: 0.9771
# Epoch 34/300
# 1/1 - 0s - 49ms/step - loss: 1.4280
# Epoch 35/300
# 1/1 - 0s - 57ms/step - loss: 1.4879
# Epoch 36/300
# 1/1 - 0s - 61ms/step - loss: 1.1547
# Epoch 37/300
# 1/1 - 0s - 41ms/step - loss: 0.6481
# Epoch 38/300
# 1/1 - 0s - 41ms/step - loss: 0.2219
# Epoch 39/300
# 1/1 - 0s - 40ms/step - loss: 0.0164
# Epoch 40/300
# 1/1 - 0s - 68ms/step - loss: 0.0333
# Epoch 41/300
# 1/1 - 0s - 52ms/step - loss: 0.1893
# Epoch 42/300
# 1/1 - 0s - 42ms/step - loss: 0.3813
# Epoch 43/300
# 1/1 - 0s - 61ms/step - loss: 0.5269
# Epoch 44/300
# 1/1 - 0s - 60ms/step - loss: 0.5803
# Epoch 45/300
# 1/1 - 0s - 41ms/step - loss: 0.5329
# Epoch 46/300
# 1/1 - 0s - 40ms/step - loss: 0.4067
# Epoch 47/300
# 1/1 - 0s - 62ms/step - loss: 0.2450
# Epoch 48/300
# 1/1 - 0s - 60ms/step - loss: 0.0992
# Epoch 49/300
# 1/1 - 0s - 41ms/step - loss: 0.0131
# Epoch 50/300
# 1/1 - 0s - 61ms/step - loss: 0.0073
# Epoch 51/300
# 1/1 - 0s - 51ms/step - loss: 0.0686
# Epoch 52/300
# 1/1 - 0s - 62ms/step - loss: 0.1547
# Epoch 53/300
# 1/1 - 0s - 53ms/step - loss: 0.2151
# Epoch 54/300
# 1/1 - 0s - 58ms/step - loss: 0.2184
# Epoch 55/300
# 1/1 - 0s - 42ms/step - loss: 0.1672
# Epoch 56/300
# 1/1 - 0s - 62ms/step - loss: 0.0920
# Epoch 57/300
# 1/1 - 0s - 40ms/step - loss: 0.0291
# Epoch 58/300
# 1/1 - 0s - 51ms/step - loss: 0.0000e+00
# Epoch 248/300
# 1/1 - 0s - 41ms/step - loss: 1.3097e-10
# Epoch 249/300
# 1/1 - 0s - 61ms/step - loss: 2.9468e-10
# Epoch 250/300
# 1/1 - 0s - 62ms/step - loss: 3.6380e-10
# Epoch 251/300
# 1/1 - 0s - 65ms/step - loss: 2.3283e-10
# Epoch 252/300
# 1/1 - 0s - 59ms/step - loss: 3.2742e-11
# Epoch 253/300
# 1/1 - 0s - 54ms/step - loss: 0.0000e+00
# Epoch 254/300
# 1/1 - 0s - 59ms/step - loss: 9.0949e-11
# Epoch 255/300
# 1/1 - 0s - 40ms/step - loss: 1.3097e-10
# Epoch 256/300
# 1/1 - 0s - 60ms/step - loss: 1.4211e-10
# Epoch 257/300
# 1/1 - 0s - 61ms/step - loss: 1.2028e-10
# Epoch 258/300
# 1/1 - 0s - 61ms/step - loss: 1.8417e-11
# Epoch 259/300
# 1/1 - 0s - 42ms/step - loss: 0.0000e+00
# Epoch 260/300
# 1/1 - 0s - 42ms/step - loss: 3.2742e-11
# Epoch 261/300
# 1/1 - 0s - 60ms/step - loss: 9.0949e-11
# Epoch 262/300
# 1/1 - 0s - 42ms/step - loss: 9.0949e-11
# Epoch 263/300
# 1/1 - 0s - 60ms/step - loss: 5.8208e-11
# Epoch 264/300
# 1/1 - 0s - 54ms/step - loss: 1.4552e-11
# Epoch 265/300
# 1/1 - 0s - 50ms/step - loss: 3.6380e-12
# Epoch 266/300
# 1/1 - 0s - 43ms/step - loss: 3.2742e-11
# Epoch 267/300
# 1/1 - 0s - 61ms/step - loss: 6.5711e-11
# Epoch 268/300
# 1/1 - 0s - 63ms/step - loss: 6.5711e-11
# Epoch 269/300
# 1/1 - 0s - 52ms/step - loss: 1.4552e-11
# Epoch 270/300
# 1/1 - 0s - 54ms/step - loss: 3.6380e-12
# Epoch 271/300
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 272/300
# 1/1 - 0s - 59ms/step - loss: 1.4552e-11
# Epoch 273/300
# 1/1 - 0s - 41ms/step - loss: 5.8208e-11
# Epoch 274/300
# 1/1 - 0s - 41ms/step - loss: 5.8208e-11
# Epoch 275/300
# 1/1 - 0s - 59ms/step - loss: 1.4552e-11
# Epoch 276/300
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 277/300
# 1/1 - 0s - 61ms/step - loss: 3.6380e-12
# Epoch 278/300
# 1/1 - 0s - 61ms/step - loss: 1.4552e-11
# Epoch 279/300
# 1/1 - 0s - 59ms/step - loss: 1.4552e-11
# Epoch 280/300
# 1/1 - 0s - 43ms/step - loss: 1.4552e-11
# Epoch 281/300
# 1/1 - 0s - 61ms/step - loss: 1.4552e-11
# Epoch 282/300
# 1/1 - 0s - 67ms/step - loss: 2.2737e-13
# Epoch 283/300
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 284/300
# 1/1 - 0s - 41ms/step - loss: 3.6380e-12
# Epoch 285/300
# 1/1 - 0s - 41ms/step - loss: 1.4552e-11
# Epoch 286/300
# 1/1 - 0s - 66ms/step - loss: 1.4552e-11
# Epoch 287/300
# 1/1 - 0s - 59ms/step - loss: 3.6380e-12
# Epoch 288/300
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 289/300
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 290/300
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 291/300
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 292/300
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 293/300
# 1/1 - 0s - 41ms/step - loss: 3.6380e-12
# Epoch 294/300
# 1/1 - 0s - 41ms/step - loss: 3.6380e-12
# Epoch 295/300
# 1/1 - 0s - 62ms/step - loss: 3.6380e-12
# Epoch 296/300
# 1/1 - 0s - 41ms/step - loss: 2.2737e-13
# Epoch 297/300
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 298/300
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 299/300
# 1/1 - 0s - 41ms/step - loss: 0.0000e+00
# Epoch 300/300
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Approximate solution: x = 2.0

# %% [markdown]
# **Code variant**

# %% [markdown]
# The next code is a variant of implementation using tf.GradientTape() for computing gradients. We obtain again the solution $x^*=2$.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define the algebraic function
def f(x):
    return x**3 - 2*x**2 + 4*x - 8

# Neural network
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

# Loss function: Mean squared value of f(x_NN)
def loss_fn():
    x = model(tf.constant([[1.0]]))  # Single input (scalar)
    return tf.reduce_mean(f(x)**2)

# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

# Training loop
for epoch in range(500):
    with tf.GradientTape() as tape:
        loss = loss_fn()
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.numpy()}")

# Solution
x_solution = model(tf.constant([[1.0]])).numpy()[0, 0]
print(f"Approximate solution: x = {x_solution}")
# Out:
# Epoch 0, Loss: 94.88030242919922
# Epoch 100, Loss: 0.23940400779247284
# Epoch 200, Loss: 7.405526503134752e-06
# Epoch 300, Loss: 1.3096723705530167e-10
# Epoch 400, Loss: 0.0
# Approximate solution: x = 2.0

# %% [markdown]
# **Synthetic Division implementation**

# %% [markdown]
# Since c=2 is a root of f(x), then (x-2) is a factor of f(x), so f(x) = (x-2) g(x). The quotient g(x) can be found using synthetic division as follows:

# %%
def synthetic_division(coeffs, c):
    """
    Perform synthetic division of a polynomial by (x - c).

    Parameters:
        coeffs (list): Coefficients [a_n, a_(n-1), ..., a_0] of the polynomial P(x) = a_n*x^n + ... + a_0.
        c (float): The value for which (x - c) is the divisor.

    Returns:
        quotient (list): Coefficients of the quotient polynomial.
        remainder (float): The remainder of the division.
    """
    quotient = [coeffs[0]]
    for coef in coeffs[1:]:
        quotient.append(coef + c * quotient[-1])
    remainder = quotient.pop()  # Last element is the remainder
    return quotient, remainder

# Given polynomial P(x) = x^3 - 2*x^2 + 4*x - 8
coeffs = [1, -2, 4, -8]
# Dividing by (x - 2), so c = 2
c = 2

quotient, remainder = synthetic_division(coeffs, c)
print("Quotient coefficients:", quotient)
print("Remainder:", remainder)
# Out:
# Quotient coefficients: [1, 0, 4]
# Remainder: 0

# %% [markdown]
# **Solving for complex solutions**

# %% [markdown]
# This indicates that $g(x) = x^2 +4$. We aim now to solve the equation
# $=x^2+4=0$,
# by representing a complex number in polar form. We use a neural network that accepts a fixed input \(t\) (dummy input) and produces a two-dimensional output
# $
# f_{\theta}(t)=(\rho_{\theta}(t),\, \varphi_{\theta}(t)).
# $
#
# We then interpret the network's output as the complex number
# $
# x_{\theta}=\rho_{\theta}\,e^{i\varphi_{\theta}}.
# $
# For the polynomial
# $
# g(x)=x^2+4,
# $
# the coefficients are $a_2=1$, $a_1=0$, and $a_0=4$.
#
#
#  Based on the formulation, the loss function is defined as:
# $
# L(\theta)=a_0^2+2\,a_0\,a_2\,\rho^2\cos(2\varphi)+\rho^4,
# $
# which, with $a_0=4$ and $a_2=1$, becomes
# $
# L(\theta)=16+8\,\rho^2\cos(2\varphi)+\rho^4.
# $
#
# The goal is to minimize this loss with respect to the network parameters $\theta$. The code is given below:

# %%
import tensorflow as tf
import numpy as np

# Polynomial coefficients for P(x) = x^2 + 4 = 0
# Here, a2 = 1 and a0 = 4.
a2 = 1.0
a0 = 4.0

# Custom loss function:
# For a given output [rho, varphi], the loss is:
# L = a0^2 + 2*a0*a2*rho^2*cos(2*varphi) + rho^4.
# This loss drives the network to adjust its outputs so that the complex number
# x = rho * exp(i*varphi) becomes a root of the polynomial.
def custom_loss(y_true, y_pred):
    # Extract the two outputs: first is rho, second is varphi.
    rho = y_pred[:, 0]
    varphi = y_pred[:, 1]
    # Compute the loss as described.
    loss = a0**2 + 2 * a0 * a2 * tf.square(rho) * tf.cos(2 * varphi) + tf.pow(rho, 4)
    return tf.reduce_mean(loss)

# Build the neural network model.
# The model takes a dummy input (a scalar) and outputs a two-dimensional vector [rho, varphi].
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(20, activation='tanh'),
    tf.keras.layers.Dense(2)  # Outputs: [rho, varphi]
])

# Compile the model with the custom loss and an Adam optimizer.
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizer, loss=custom_loss)

# Since the loss depends solely on the network's output, we use a dummy input.
t = 1.0  # The input can be any fixed number.
dummy_input = np.array([[t]])
dummy_target = np.array([[0.0, 0.0]])  # Dummy target (not used in the loss)

# Train the model.
model.fit(dummy_input, dummy_target, epochs=500, verbose=2)

# Extract the outputs from the trained model.
output = model.predict(dummy_input)
rho = output[0, 0]
varphi = output[0, 1]
# Construct the approximate complex solution in polar form.
solution1 = rho * np.exp(1j * varphi)
print("Approximate complex solution:", solution1)
solution2 = rho * np.exp(-1j * varphi)
print("Approximate complex solution:", solution2)
# Out:
# Epoch 1/500
# 1/1 - 2s - 2s/step - loss: 16.0222
# Epoch 2/500
# 1/1 - 0s - 94ms/step - loss: 16.0937
# Epoch 3/500
# 1/1 - 0s - 59ms/step - loss: 16.0198
# Epoch 4/500
# 1/1 - 0s - 45ms/step - loss: 16.0037
# Epoch 5/500
# 1/1 - 0s - 49ms/step - loss: 16.0289
# Epoch 6/500
# 1/1 - 0s - 60ms/step - loss: 16.0277
# Epoch 7/500
# 1/1 - 0s - 43ms/step - loss: 16.0111
# Epoch 8/500
# 1/1 - 0s - 62ms/step - loss: 16.0015
# Epoch 9/500
# 1/1 - 0s - 45ms/step - loss: 16.0000
# Epoch 10/500
# 1/1 - 0s - 42ms/step - loss: 15.9996
# Epoch 11/500
# 1/1 - 0s - 59ms/step - loss: 15.9960
# Epoch 12/500
# 1/1 - 0s - 60ms/step - loss: 15.9837
# Epoch 13/500
# 1/1 - 0s - 43ms/step - loss: 15.9454
# Epoch 14/500
# 1/1 - 0s - 43ms/step - loss: 15.8281
# Epoch 15/500
# 1/1 - 0s - 60ms/step - loss: 15.5259
# Epoch 16/500
# 1/1 - 0s - 59ms/step - loss: 14.9312
# Epoch 17/500
500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 417/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 418/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 419/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 420/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 421/500
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 422/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 423/500
# 1/1 - 0s - 63ms/step - loss: 0.0000e+00
# Epoch 424/500
# 1/1 - 0s - 58ms/step - loss: 0.0000e+00
# Epoch 425/500
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 426/500
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 427/500
# 1/1 - 0s - 42ms/step - loss: 0.0000e+00
# Epoch 428/500
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 429/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 430/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 431/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 432/500
# 1/1 - 0s - 71ms/step - loss: 0.0000e+00
# Epoch 433/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 434/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 435/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 436/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 437/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 438/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 439/500
# 1/1 - 0s - 48ms/step - loss: 0.0000e+00
# Epoch 440/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 441/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 442/500
# 1/1 - 0s - 58ms/step - loss: 0.0000e+00
# Epoch 443/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 444/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 445/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 446/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 447/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 448/500
# 1/1 - 0s - 48ms/step - loss: 0.0000e+00
# Epoch 449/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 450/500
# 1/1 - 0s - 69ms/step - loss: 0.0000e+00
# Epoch 451/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 452/500
# 1/1 - 0s - 47ms/step - loss: 0.0000e+00
# Epoch 453/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 454/500
# 1/1 - 0s - 46ms/step - loss: 0.0000e+00
# Epoch 455/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 456/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 457/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 458/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 459/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 460/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 461/500
# 1/1 - 0s - 62ms/step - loss: 0.0000e+00
# Epoch 462/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 463/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 464/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 465/500
# 1/1 - 0s - 43ms/step - loss: 0.0000e+00
# Epoch 466/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 467/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 468/500
# 1/1 - 0s - 69ms/step - loss: 0.0000e+00
# Epoch 469/500
# 1/1 - 0s - 49ms/step - loss: 0.0000e+00
# Epoch 470/500
# 1/1 - 0s - 46ms/step - loss: 0.0000e+00
# Epoch 471/500
# 1/1 - 0s - 46ms/step - loss: 0.0000e+00
# Epoch 472/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 473/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 474/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 475/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 476/500
# 1/1 - 0s - 58ms/step - loss: 0.0000e+00
# Epoch 477/500
# 1/1 - 0s - 42ms/step - loss: 0.0000e+00
# Epoch 478/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 479/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 480/500
# 1/1 - 0s - 42ms/step - loss: 0.0000e+00
# Epoch 481/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 482/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 483/500
# 1/1 - 0s - 46ms/step - loss: 0.0000e+00
# Epoch 484/500
# 1/1 - 0s - 58ms/step - loss: 0.0000e+00
# Epoch 485/500
# 1/1 - 0s - 67ms/step - loss: 0.0000e+00
# Epoch 486/500
# 1/1 - 0s - 57ms/step - loss: 0.0000e+00
# Epoch 487/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 488/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 489/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 490/500
# 1/1 - 0s - 45ms/step - loss: 0.0000e+00
# Epoch 491/500
# 1/1 - 0s - 58ms/step - loss: 0.0000e+00
# Epoch 492/500
# 1/1 - 0s - 61ms/step - loss: 0.0000e+00
# Epoch 493/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# Epoch 494/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 495/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 496/500
# 1/1 - 0s - 57ms/step - loss: 0.0000e+00
# Epoch 497/500
# 1/1 - 0s - 60ms/step - loss: 0.0000e+00
# Epoch 498/500
# 1/1 - 0s - 44ms/step - loss: 0.0000e+00
# Epoch 499/500
# 1/1 - 0s - 62ms/step - loss: 0.0000e+00
# Epoch 500/500
# 1/1 - 0s - 59ms/step - loss: 0.0000e+00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Approximate complex solution: (8.742278e-08+2j)
# Approximate complex solution: (8.742278e-08-2j)

# %% [markdown]
# We obtained two complex conjugate solutions, 2i and -2i. The real part is a zero machine number and it is discarded.

# %% [markdown]
# **The Supervised Inverse Construction**

# %% [markdown]
# In this construction we generate data and infer the inverse function $f^{-1}(y)$ from data. The graph of the inverse is provided.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Define the function f(x)
def f(x):
    return x**3 - 2*x**2 + 4*x - 8

# Generate training data
x_train = np.linspace(-4, 5, 1000).reshape(-1, 1)  # Sample x values
y_train = f(x_train)  # Compute corresponding y values

# Build the neural network
model = Sequential([
    Dense(80, activation='tanh', input_dim=1),  # Hidden layer with 10 neurons
    #Dense(100, activation='tanh'),  # Another hidden layer
    Dense(1)  # Output layer
])

# Compile the model with mean squared error loss
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# Train the model
model.fit(y_train, x_train, epochs=100, batch_size=32, verbose=1)

# Generate a range of y values for testing
y_vals = np.linspace(-100, 100, 1000).reshape(-1, 1)

# Use the trained model to predict the inverse function values (f^{-1}(y))
x_preds = model.predict(y_vals)

# Plot the inverse function
plt.figure(figsize=(8, 6))
plt.plot(0, 2, "ro", markersize=8)  # Plot the point (0,2) in red
plt.plot(y_vals, x_preds, label="$f^{-1}(y)$", linewidth=2)
plt.title("Inverse Function $f^{-1}(y)$", fontsize=16)
plt.xlabel("$y$", fontsize=14)
plt.ylabel("$x = f^{-1}(y)$", fontsize=14)
plt.grid(alpha=0.3)
plt.legend(fontsize=12)
plt.show()
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4182
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0487
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0150
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8835e-04
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5582e-04
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6860e-04
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4650e-04
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7680e-04
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6752e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7257e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0203e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3500e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8187e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# To solve the equation $f(x)=0$, using the inverse, we obtain $x=f^{-1}(0)$. From the graph we notice that $f^{-1}(0) =2$, since $(0,2)$ is a point on the graph of $f^{-1}$.

# %% [markdown]
# **The Unsupervised Inverse Construction**

# %% [markdown]
# This construction uses the functional equation $f(f^{-1}(y)) =y$ to find t

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Define the function f(x)
def f(x):
    return x**3 - 2*x**2 + 4*x - 8

# Generate y values for training
y_train = np.linspace(-50, 50, 1000).reshape(-1, 1)  # Sample y values

# Build the neural network
model = Sequential([
    Dense(50, activation='tanh', input_dim=1),  # Hidden layer with 50 neurons
    Dense(20, activation='tanh'),  # Another hidden layer
    Dense(1)  # Output layer
])

# Define the custom loss function
def unsupervised_loss(y_true, y_pred):
    # Compute f(NN(y)) - y
    return tf.reduce_mean(tf.square(f(y_pred) - y_true))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss=unsupervised_loss)

# Train the model
model.fit(y_train, y_train, epochs=100, batch_size=32, verbose=1)  # Note: y_train is used as both input and target

# Generate y values for plotting the inverse function
y_vals = np.linspace(-50, 50, 1000).reshape(-1, 1)

# Predict x values using the trained model
x_preds = model.predict(y_vals)

# Plot the inverse function
plt.figure(figsize=(8, 6))
plt.plot(y_vals, x_preds, label="$f^{-1}(y)$", linewidth=2)
plt.title("Inverse Function $f^{-1}(y)$ Learned via Unsupervised Learning", fontsize=16)
plt.xlabel("$y$", fontsize=14)
plt.ylabel("$x = f^{-1}(y)$", fontsize=14)
plt.grid(alpha=0.3)
plt.legend(fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 489.5349
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.0159
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8572
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7396
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0428
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3036
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2777
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7488
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8364
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7859
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7697
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1802
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2181
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8263
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6658
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2494
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2260
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8340
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.7108
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2462
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1035
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2765
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1762
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1398
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1784
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3458
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5030
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9372
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4192
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4997
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1047
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2249
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0325
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1889
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1458
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3337
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7812
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4725
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8783
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6547
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1210
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2545
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0509
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0432
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0281
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1541
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0477
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4668
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0573
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0133
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8540
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1132
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6182
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4242
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8171
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0532
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0482
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0423
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0307
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0954
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2376
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9766
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2644
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0939
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1265
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1722
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9363
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2423
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2888
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8949
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7963
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3014
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9605
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5575
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3000
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0566
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0900
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2445
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5429
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5165
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7440
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2415
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8852
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2448
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2240
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1053
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1963
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9598
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2806
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1592
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0509
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0338
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0461
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3264
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1222
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1834
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2003
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7424
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
